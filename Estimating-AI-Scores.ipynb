# %%
# Import packages
# %matplotlib inline
import matplotlib.pyplot as plt #matplotlib
import numpy as np #numpy
import pandas as pd #pandas
from sklearn.cross_validation import train_test_split
import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
from sklearn import datasets
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFECV
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.feature_selection import f_regression
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from pandas.tools.plotting import scatter_matrix

# %%
# Import file
acounts = pd.read_csv('2017_07_14-ArticleCountsperJournal.txt', sep='\t')
# remove duplicate rows (except for first occurrence)
acounts.drop_duplicates(keep='first', inplace=True)

# %%
acounts.head(3)
# Out:
#         ISSN                               journal_name  citation_count  \
# 0  2450-5102  hungarian journal of industrial chemistry               8
# 1  2093-6214    journal of pharmaceutical investigation             551
# 2  1475-2867                  cancer cell international            4612
#
#    journal_id  paper_count
# 0   112891560            9
# 1    70884739         1590
# 2   130214813          762

# %%
#Import file
aiscores = pd.read_csv('api_influence7-20-17.csv', sep=",")

# %%
aiscores.head(3)
# Out:
#     id  article_influence  est_article_influence  date_stamp journal_id  \
# 0  144            0.37613                    NaN  2007-12-31  0187-6236
# 1  145            1.27820                    NaN  2007-12-31  0021-9150
# 2  146            1.33810                    NaN  2007-12-31  1478-6362
#
#    ai_percentile  cost_effectiveness  ef_percentile  eigenfactor  efn
# 0            NaN                 NaN            NaN          NaN  NaN
# 1            NaN                 NaN            NaN          NaN  NaN
# 2            NaN                 NaN            NaN          NaN  NaN

# %%
# Find all the 2015 ai scores
ai2015 = aiscores.loc[aiscores['date_stamp'] == '2015-12-31']

# %%
ai2015.head(2)
# Out:
#         id  article_influence  est_article_influence  date_stamp journal_id  \
# 5716  5860             12.463                    NaN  2015-12-31  1433-8351
# 5717  5861              5.459                    NaN  2015-12-31  1369-7021
#
#       ai_percentile  cost_effectiveness  ef_percentile  eigenfactor  efn
# 5716            NaN                 NaN            NaN          NaN  NaN
# 5717            NaN                 NaN            NaN          NaN  NaN

# %%
# Create a new dataframe that merges acounts and ai2015
merged = pd.merge(acounts, ai2015, left_on='ISSN', right_on='journal_id')

# %%
merged.head(5)
# Out:
#         ISSN                                 journal_name  citation_count  \
# 0  1475-2867                    cancer cell international            4612
# 1  1744-9081               behavioral and brain functions           18785
# 2  1944-3277                standards in genomic sciences            2016
# 3  1476-072X  international journal of health geographics           26592
# 4  1436-4522             educational technology & society           17076
#
#    journal_id_x  paper_count    id  article_influence  est_article_influence  \
# 0     130214813          762  6102              0.588                    NaN
# 1     202417740          579  6187              0.693                    NaN
# 2     174963459          615  6439              0.422                    NaN
# 3      28612791          684  6034              1.010                    NaN
# 4     187377680         2168  6318              0.384                    NaN
#
#    date_stamp journal_id_y  ai_percentile  cost_effectiveness  ef_percentile  \
# 0  2015-12-31    1475-2867            NaN                 NaN            NaN
# 1  2015-12-31    1744-9081            NaN                 NaN            NaN
# 2  2015-12-31    1944-3277            NaN                 NaN            NaN
# 3  2015-12-31    1476-072X            NaN                 NaN            NaN
# 4  2015-12-31    1436-4522            NaN                 NaN            NaN
#
#    eigenfactor  efn
# 0          NaN  NaN
# 1          NaN  NaN
# 2          NaN  NaN
# 3          NaN  NaN
# 4          NaN  NaN

# %%
# Add a column that calculates the average citations per paper per journal
merged['avg_cites_per_paper'] = merged['citation_count'] / merged['paper_count']

# %%
merged.head(3)
# Out:
#         ISSN                    journal_name  citation_count  journal_id_x  \
# 0  1475-2867       cancer cell international            4612     130214813
# 1  1744-9081  behavioral and brain functions           18785     202417740
# 2  1944-3277   standards in genomic sciences            2016     174963459
#
#    paper_count    id  article_influence  est_article_influence  date_stamp  \
# 0          762  6102              0.588                    NaN  2015-12-31
# 1          579  6187              0.693                    NaN  2015-12-31
# 2          615  6439              0.422                    NaN  2015-12-31
#
#   journal_id_y  ai_percentile  cost_effectiveness  ef_percentile  eigenfactor  \
# 0    1475-2867            NaN                 NaN            NaN          NaN
# 1    1744-9081            NaN                 NaN            NaN          NaN
# 2    1944-3277            NaN                 NaN            NaN          NaN
#
#    efn  avg_cites_per_paper
# 0  NaN             6.052493
# 1  NaN            32.443869
# 2  NaN             3.278049

# %%
# Quick plot of article influence score and average citations per paper per journal
plt.plot(merged['article_influence'], merged['avg_cites_per_paper'], 'o')
plt.xlabel('2015 AI Score for Given Journal')
plt.ylabel('Avg Citations per Paper for Given Journal')

plt.savefig('ai_avg_citation_scatterplot.jpg')

# %%
# Check linear regression results
linregress(merged['article_influence'], merged['avg_cites_per_paper'])
# Out:
# LinregressResult(slope=4.0835852489503166, intercept=7.566289282849195, rvalue=0.27872078724894739, pvalue=1.01518940477298e-07, stderr=0.75103171798427193)

# %%
# Read in new file
citation_counts_by_year = pd.read_csv('2017_07_14-year_jid_count.txt', header=None, 
                                      sep=' ', names=['year', 'journal_id', 'citation_count'])
# remove duplicate rows (except for first occurrence)
citation_counts_by_year.drop_duplicates(keep='first', inplace=True)

# %%
citation_counts_by_year.tail(5)
# Out:
#        year  journal_id  citation_count
# 19660  2011   179257517              47
# 19661  2012   179257517              69
# 19662  2013   179257517             105
# 19663  2014   179257517             165
# 19664  2015   179257517              43

# %%
#Read in file
paper_counts_by_year = pd.read_csv('2017_07_20-papers_per_year.txt', sep=' ')
# remove duplicate rows (except for first occurrence)
paper_counts_by_year.drop_duplicates(keep='first', inplace=True)

# %%
paper_counts_by_year.head(5)
# Out:
#    year  journal_id  paper_count
# 0  2010   124795565          891
# 1  2011   124795565          880
# 2  2012   124795565          854
# 3  2013   124795565          869
# 4  2014   124795565          717

# %%
# Outer join the dataframes on journal_id and year, introducing NAs if necessary
by_year_merged = pd.merge(citation_counts_by_year, paper_counts_by_year, on=('journal_id','year'), how='outer')

# %%
by_year_merged.head(10)
# Out:
#    year  journal_id  citation_count  paper_count
# 0  2010   166203837          1447.0          NaN
# 1  2011   166203837          1676.0          NaN
# 2  2012   166203837          1813.0          NaN
# 3  2013   166203837          2007.0          NaN
# 4  2014   166203837          2078.0          NaN
# 5  2015   166203837          1458.0          NaN
# 6  2010    72004196           135.0          NaN
# 7  2011    72004196           173.0          NaN
# 8  2012    72004196           211.0          NaN
# 9  2013    72004196           335.0          NaN

# %%
# Left join with acounts df
by_year_merged = pd.merge(by_year_merged, acounts[['journal_id', 'ISSN','journal_name']], on='journal_id', how='left')

# %%
# save to csv
by_year_merged.to_csv('counts_by_year.csv', sep=',')

# %%
# create new column of average citations per paper per journal
by_year_merged['avg_cites_per_paper'] = by_year_merged['citation_count'] / by_year_merged['paper_count']

# %%
by_year_merged.head(10)
# Out:
#    year  journal_id  citation_count  paper_count       ISSN  \
# 0  2010   166203837          1447.0          NaN  0001-527X
# 1  2011   166203837          1676.0          NaN  0001-527X
# 2  2012   166203837          1813.0          NaN  0001-527X
# 3  2013   166203837          2007.0          NaN  0001-527X
# 4  2014   166203837          2078.0          NaN  0001-527X
# 5  2015   166203837          1458.0          NaN  0001-527X
# 6  2010    72004196           135.0          NaN  0003-0090
# 7  2011    72004196           173.0          NaN  0003-0090
# 8  2012    72004196           211.0          NaN  0003-0090
# 9  2013    72004196           335.0          NaN  0003-0090
#
#                                         journal_name  avg_cites_per_paper
# 0                           acta biochimica polonica                  NaN
# 1                           acta biochimica polonica                  NaN
# 2                           acta biochimica polonica                  NaN
# 3                           acta biochimica polonica                  NaN
# 4                           acta biochimica polonica                  NaN
# 5                           acta biochimica polonica                  NaN
# 6  bulletin of the american museum of natural his...                  NaN
# 7  bulletin of the american museum of natural his...                  NaN
# 8  bulletin of the american museum of natural his...                  NaN
# 9  bulletin of the american museum of natural his...                  NaN

# %%
# Create a pivot table to show sum of citation counts, sum of paper counts, and number of years 
# included for each journal
counts_pivot_table = pd.pivot_table(by_year_merged, 
                                 index=['journal_name', 'ISSN'],
                                    values=['citation_count', 'paper_count'],
                                    aggfunc=[np.sum, len], margins=True)
counts_pivot_table.head(5)
# Out:
#                                                    sum              \
#                                         citation_count paper_count
# journal_name                  ISSN
# 3d research                   2092-6731          249.0       175.0
# aaps pharmscitech             1530-9932        12172.0      1113.0
# aba journal                   2275-6639            1.0         1.0
# abstract and applied analysis 1687-0409         6723.0      4805.0
# academic psychiatry           1545-7230         2729.0      1735.0
#
#                                                    len
#                                         citation_count paper_count
# journal_name                  ISSN
# 3d research                   2092-6731            6.0         6.0
# aaps pharmscitech             1530-9932            6.0         6.0
# aba journal                   2275-6639            2.0         2.0
# abstract and applied analysis 1687-0409            6.0         6.0
# academic psychiatry           1545-7230            6.0         6.0

# %%
# sum and len will now become rows
counts_pivot_table = counts_pivot_table.stack(level=0)

# %%
# create new column with average citation count per paper per journal over the 6 years
counts_pivot_table['avg_cites_per_paper'] = counts_pivot_table['citation_count'] / counts_pivot_table['paper_count']

# %%
# unstack and place sum and len back in columns
counts_pivot_table = counts_pivot_table.unstack()

# %%
# Flatten pivot table for easier indexing
counts_pivot_table.columns = counts_pivot_table.columns.to_series().str.join('_')

# %%
# Keep only specific columns
counts_pivot_table = counts_pivot_table[['citation_count_sum', 'citation_count_len', 'paper_count_sum', 'avg_cites_per_paper_sum']]

# %%
# Rename certain columns
counts_pivot_table.rename(columns={'citation_count_len': 'number_years_captured',
                                   'avg_cites_per_paper_sum': 'avg_cites_per_paper'}, inplace=True)
# Remove row #2 (total over all journals) not needed
counts_pivot_table = counts_pivot_table.drop(counts_pivot_table.index[1])

# %%
# Reset the index
counts_pivot_table = counts_pivot_table.reset_index()
counts_pivot_table.head(5)
# Out:
#                     journal_name       ISSN  citation_count_sum  \
# 0                    3d research  2092-6731               249.0
# 1              aaps pharmscitech  1530-9932             12172.0
# 2                    aba journal  2275-6639                 1.0
# 3  abstract and applied analysis  1687-0409              6723.0
# 4            academic psychiatry  1545-7230              2729.0
#
#    number_years_captured  paper_count_sum  avg_cites_per_paper
# 0                    6.0            175.0             1.422857
# 1                    6.0           1113.0            10.936208
# 2                    2.0              1.0             1.000000
# 3                    6.0           4805.0             1.399168
# 4                    6.0           1735.0             1.572911

# %%
# Need to add article influence data - join ai2015 table
pivot_table_merged = pd.merge(counts_pivot_table, ai2015[['article_influence', 'journal_id']], 
                              left_on='ISSN', right_on='journal_id')
# Only keep rows in which year == 6 (this will remove newer or short-lived journals)
pivot_table_merged = pivot_table_merged.loc[pivot_table_merged['number_years_captured'] == 6.0]
pivot_table_merged
# Out:
#                                           journal_name       ISSN  \
# 0                                       acta bioethica  1726-569X
# 1                               acta botanica croatica  0365-0588
# 2                                  acta medica okayama  0386-300X
# 3                               acta medica portuguesa  1646-0758
# 4                   acta neurobiologiae experimentalis  0065-1400
# 5                            acta scientiarum-agronomy  1807-8621
# 6      acta zoologica academiae scientiarum hungaricae  1217-8837
# 7                                            adansonia  1280-8571
# 8                     advances in difference equations  1687-1847
# 9                   advances in mechanical engineering  1687-8140
# 10                           aids research and therapy  1742-6405
# 11                                        aip advances  2158-3226
# 12                    algorithms for molecular biology  1748-7188
# 13                                         amb express  2191-0855
# 14   annals of clinical microbiology and antimicrob...  1476-0711
# 15                        annals of general psychiatry  1744-859X
# 16               annals of indian academy of neurology  0972-2327
# 17                            annals of intensive care  2110-5820
# 18                         annals of thoracic medicine  1817-1737
# 19                                          aob plants  2041-2851
# 21                                     aquatic biology  1864-7790
# 22                archives of metallurgy and materials  1733-3490
# 23                        arthritis research & therapy  1478-6354
# 24                                           asn neuro  1759-0914
# 25                                          atmosphere  2073-4433
# 26                         atmospheric science letters  1530-261X
# 27                bangladesh journal of plant taxonomy  1028-2092
# 28                      behavioral and brain functions  1744-9081
# 29              beilstein journal of organic chemistry  1860-5397
# 30                                      biodata mining  1756-0381
# ..                                                 ...        ...
# 321                                    salud colectiva  1851-8265
# 322  scandinavian journal of trauma, resuscitation ...  1757-7241
# 323                               science of sintering  0350-820X
# 324                                  scientia agricola  1678-992X
# 325                                 scientific reports  2045-2322
# 326                                            sensors  1424-8220
# 328                                               sola  1349-6476
# 329  south african journal of economic and manageme...  2222-3436
# 330    south african journal of industrial engineering  2224-7890
# 331                      standards in genomic sciences  1944-3277
# 332                       stem cell research & therapy  1757-6512
# 333    substance abuse treatment prevention and policy  1747-597X
# 334                                     sustainability  2071-1050
# 335                                           symmetry  2073-8994
# 336  symmetry integrability and geometry-methods an...  1815-0659
# 337                                           tellus a  1600-0870
# 338  the international food and agribusiness manage...  1559-2448
# 339                                   the plant genome  1940-3372
# 340          theoretical biology and medical modelling  1742-4682
# 341          therapeutics and clinical risk management  1178-203X
# 342                                    thermal science  0354-9836
# 343                           tobacco induced diseases  1617-9625
# 344                                             toxins  2072-6651
# 345                             translational oncology  1936-5233
# 347                                             trials  1745-6215
# 348                               veterinarni medicina  0375-8427
# 349                                   virology journal  1743-422X
# 350                                              water  2073-4441
# 351                 world journal of emergency surgery  1749-7922
# 352                 world journal of surgical oncology  1477-7819
#
#      citation_count_sum  number_years_captured  paper_count_sum  \
# 0                 135.0                    6.0            490.0
# 1                 645.0                    6.0            209.0
# 2                2625.0                    6.0            325.0
# 3                 964.0                    6.0            979.0
# 4                4243.0                    6.0            604.0
# 5                 832.0                    6.0           1131.0
# 6                  69.0                    6.0              9.0
# 7                 157.0                    6.0            139.0
# 8                2610.0                    6.0           1590.0
# 9                1091.0                    6.0           2160.0
# 10               1881.0                    6.0            247.0
# 11               2576.0                    6.0           2574.0
# 12               1382.0                    6.0            192.0
# 13               1203.0                    6.0            401.0
# 14               2855.0                    6.0            254.0
# 15               2329.0                    6.0            454.0
# 16               1155.0                    6.0            798.0
# 17               1585.0                    6.0            263.0
# 18               1201.0                    6.0            353.0
# 19                946.0                    6.0            412.0
# 21               3354.0                    6.0            435.0
# 22               1118.0                    6.0           1210.0
# 23              34503.0                    6.0           2313.0
# 24               1747.0                    6.0            174.0
# 25                586.0                    6.0            516.0
# 26               2929.0                    6.0            518.0
# 27                217.0                    6.0            149.0
# 28               5072.0                    6.0            326.0
# 29               6167.0                    6.0           1552.0
# 30                719.0                    6.0            163.0
# ..                  ...                    ...              ...
# 321               111.0                    6.0            407.0
# 322              2254.0                    6.0            839.0
# 323               566.0                    6.0            185.0
# 324              4593.0                    6.0            599.0
# 325             29396.0                    6.0          13260.0
# 326             39346.0                    6.0           7717.0
# 328              1765.0                    6.0            265.0
# 329               367.0                    6.0            421.0
# 330               230.0                    6.0            498.0
# 331              1388.0                    6.0            566.0
# 332              2775.0                    6.0            739.0
# 333              1750.0                    6.0            252.0
# 334              4624.0                    6.0           2239.0
# 335               705.0                    6.0            335.0
# 336              1386.0                    6.0            547.0
# 337             13727.0                    6.0            699.0
# 338              1403.0                    6.0            238.0
# 339              1725.0                    6.0            164.0
# 340              2747.0                    6.0            312.0
# 341              3998.0                    6.0            564.0
# 342              2062.0                    6.0           1303.0
# 343               807.0                    6.0            185.0
# 344              4389.0                    6.0           1047.0
# 345              2655.0                    6.0            400.0
# 347             11452.0                    6.0           2852.0
# 348               977.0                    6.0            436.0
# 349             17658.0                    6.0           2111.0
# 350              1837.0                    6.0            905.0
# 351              1568.0                    6.0            314.0
# 352              8119.0                    6.0           1638.0
#
#      avg_cites_per_paper  article_influence journal_id
# 0               0.275510              0.030  1726-569X
# 1               3.086124              0.181  0365-0588
# 2               8.076923              0.230  0386-300X
# 3               0.984678              0.112  1646-0758
# 4               7.024834              0.506  0065-1400
# 5               0.735632              0.307  1807-8621
# 6               7.666667              0.187  1217-8837
# 7               1.129496              0.193  1280-8571
# 8               1.641509              0.113  1687-1847
# 9               0.505093              0.198  1687-8140
# 10              7.615385              0.601  1742-6405
# 11              1.000777              0.452  2158-3226
# 12              7.197917              1.902  1748-7188
# 13              3.000000              0.566  2191-0855
# 14             11.240157              0.740  1476-0711
# 15              5.129956              0.416  1744-859X
# 16              1.447368              0.224  0972-2327
# 17              6.026616              1.366  2110-5820
# 18              3.402266              0.369  1817-1737
# 19              2.296117              0.737  2041-2851
# 21              7.710345              0.521  1864-7790
# 22              0.923967              0.117  1733-3490
# 23             14.916991              1.559  1478-6354
# 24             10.040230              1.145  1759-0914
# 25              1.135659              0.520  2073-4433
# 26              5.654440              0.768  1530-261X
# 27              1.456376              0.080  1028-2092
# 28             15.558282              0.693  1744-9081
# 29              3.973582              0.683  1860-5397
# 30              4.411043              0.668  1756-0381
# ..                   ...                ...        ...
# 321             0.272727              0.077  1851-8265
# 322             2.686532              0.782  1757-7241
# 323             3.059459              0.134  0350-820X
# 324             7.667780              0.345  1678-992X
# 325             2.216893              1.482  2045-2322
# 326             5.098613              0.546  1424-8220
# 328             6.660377              0.605  1349-6476
# 329             0.871734              0.077  2222-3436
# 330             0.461847              0.076  2224-7890
# 331             2.452297              0.422  1944-3277
# 332             3.755074              1.123  1757-6512
# 333             6.944444              0.628  1747-597X
# 334             2.065208              0.333  2071-1050
# 335             2.104478              0.430  2073-8994
# 336             2.533821              0.611  1815-0659
# 337            19.638054              1.033  1600-0870
# 338             5.894958              0.167  1559-2448
# 339            10.518293              1.287  1940-3372
# 340             8.804487              0.376  1742-4682
# 341             7.088652              0.490  1178-203X
# 342             1.582502              0.147  0354-9836
# 343             4.362162              0.673  1617-9625
# 344             4.191977              0.805  2072-6651
# 345             6.637500              0.854  1936-5233
# 347             4.015428              0.893  1745-6215
# 348             2.240826              0.217  0375-8427
# 349             8.364756              0.635  1743-422X
# 350             2.029834              0.435  2073-4441
# 351             4.993631              0.557  1749-7922
# 352             4.956654              0.392  1477-7819
#
# [341 rows x 8 columns]

# %%
plt.plot(pivot_table_merged['article_influence'], pivot_table_merged['avg_cites_per_paper'], 'o')
plt.xlabel('2015 AI Score for Given Journal')
plt.ylabel('Avg Citations per Paper for Given Journal 6 Years \n 2010-2015')

plt.savefig('ai_avg_citation_5_years_scatterplot.jpg')

# %%
# Try a log log plot because of the density of most points
plt.plot(np.log(pivot_table_merged['article_influence']), np.log(pivot_table_merged['avg_cites_per_paper']), 'o')
plt.xlabel('log 2015 AI Score for Given Journal')
plt.ylabel('log Avg Citations per Paper for Given Journal 6 Years \n 2010-2015')

plt.savefig('ai_avg_citation_5_years_scatterplot_log_log.jpg')

# %%
plt.plot(pivot_table_merged['article_influence'], pivot_table_merged['avg_cites_per_paper'], 'o')
plt.xlabel('2015 AI Score for Given Journal')
plt.ylabel('Avg Citations per Paper for Given Journal 6 Years \n 2010-2015')
plt.xlim(0,13)
plt.ylim(0,70)

plt.savefig('ai_avg_citation_5_years_scatterplot_zoomed.jpg')

# %%
mask = ~np.isnan(pivot_table_merged['article_influence']) & ~np.isnan(pivot_table_merged['avg_cites_per_paper'])
linregress(pivot_table_merged['article_influence'][mask], pivot_table_merged['avg_cites_per_paper'][mask])
# Out:
# LinregressResult(slope=2.8381638747589903, intercept=5.8630182583180499, rvalue=0.14123056048556826, pvalue=0.0093246181474941313, stderr=1.0853358124970376)

# %% [markdown]
# Why are there NAs? What are they?

# %%
nan_rows = pivot_table_merged[pivot_table_merged.isnull().T.any().T]
nan_rows
# Out:
#                      journal_name       ISSN  citation_count_sum  \
# 212           journal of genetics  0022-1333              5000.0
# 243                   kybernetika  0023-5954              1542.0
# 317  revista de biologia tropical  0034-7744              3249.0
#
#      number_years_captured  paper_count_sum  avg_cites_per_paper  \
# 212                    6.0              NaN                  NaN
# 243                    6.0              NaN                  NaN
# 317                    6.0              NaN                  NaN
#
#      article_influence journal_id
# 212              0.278  0022-1333
# 243              0.273  0023-5954
# 317              0.166  0034-7744

# %%
# Remove the 3 rows
pivot_table_merged = pivot_table_merged.dropna(subset=['paper_count_sum'])

# %%
pivot_table_merged
# Out:
#                                           journal_name       ISSN  \
# 0                                       acta bioethica  1726-569X
# 1                               acta botanica croatica  0365-0588
# 2                                  acta medica okayama  0386-300X
# 3                               acta medica portuguesa  1646-0758
# 4                   acta neurobiologiae experimentalis  0065-1400
# 5                            acta scientiarum-agronomy  1807-8621
# 6      acta zoologica academiae scientiarum hungaricae  1217-8837
# 7                                            adansonia  1280-8571
# 8                     advances in difference equations  1687-1847
# 9                   advances in mechanical engineering  1687-8140
# 10                           aids research and therapy  1742-6405
# 11                                        aip advances  2158-3226
# 12                    algorithms for molecular biology  1748-7188
# 13                                         amb express  2191-0855
# 14   annals of clinical microbiology and antimicrob...  1476-0711
# 15                        annals of general psychiatry  1744-859X
# 16               annals of indian academy of neurology  0972-2327
# 17                            annals of intensive care  2110-5820
# 18                         annals of thoracic medicine  1817-1737
# 19                                          aob plants  2041-2851
# 21                                     aquatic biology  1864-7790
# 22                archives of metallurgy and materials  1733-3490
# 23                        arthritis research & therapy  1478-6354
# 24                                           asn neuro  1759-0914
# 25                                          atmosphere  2073-4433
# 26                         atmospheric science letters  1530-261X
# 27                bangladesh journal of plant taxonomy  1028-2092
# 28                      behavioral and brain functions  1744-9081
# 29              beilstein journal of organic chemistry  1860-5397
# 30                                      biodata mining  1756-0381
# ..                                                 ...        ...
# 321                                    salud colectiva  1851-8265
# 322  scandinavian journal of trauma, resuscitation ...  1757-7241
# 323                               science of sintering  0350-820X
# 324                                  scientia agricola  1678-992X
# 325                                 scientific reports  2045-2322
# 326                                            sensors  1424-8220
# 328                                               sola  1349-6476
# 329  south african journal of economic and manageme...  2222-3436
# 330    south african journal of industrial engineering  2224-7890
# 331                      standards in genomic sciences  1944-3277
# 332                       stem cell research & therapy  1757-6512
# 333    substance abuse treatment prevention and policy  1747-597X
# 334                                     sustainability  2071-1050
# 335                                           symmetry  2073-8994
# 336  symmetry integrability and geometry-methods an...  1815-0659
# 337                                           tellus a  1600-0870
# 338  the international food and agribusiness manage...  1559-2448
# 339                                   the plant genome  1940-3372
# 340          theoretical biology and medical modelling  1742-4682
# 341          therapeutics and clinical risk management  1178-203X
# 342                                    thermal science  0354-9836
# 343                           tobacco induced diseases  1617-9625
# 344                                             toxins  2072-6651
# 345                             translational oncology  1936-5233
# 347                                             trials  1745-6215
# 348                               veterinarni medicina  0375-8427
# 349                                   virology journal  1743-422X
# 350                                              water  2073-4441
# 351                 world journal of emergency surgery  1749-7922
# 352                 world journal of surgical oncology  1477-7819
#
#      citation_count_sum  number_years_captured  paper_count_sum  \
# 0                 135.0                    6.0            490.0
# 1                 645.0                    6.0            209.0
# 2                2625.0                    6.0            325.0
# 3                 964.0                    6.0            979.0
# 4                4243.0                    6.0            604.0
# 5                 832.0                    6.0           1131.0
# 6                  69.0                    6.0              9.0
# 7                 157.0                    6.0            139.0
# 8                2610.0                    6.0           1590.0
# 9                1091.0                    6.0           2160.0
# 10               1881.0                    6.0            247.0
# 11               2576.0                    6.0           2574.0
# 12               1382.0                    6.0            192.0
# 13               1203.0                    6.0            401.0
# 14               2855.0                    6.0            254.0
# 15               2329.0                    6.0            454.0
# 16               1155.0                    6.0            798.0
# 17               1585.0                    6.0            263.0
# 18               1201.0                    6.0            353.0
# 19                946.0                    6.0            412.0
# 21               3354.0                    6.0            435.0
# 22               1118.0                    6.0           1210.0
# 23              34503.0                    6.0           2313.0
# 24               1747.0                    6.0            174.0
# 25                586.0                    6.0            516.0
# 26               2929.0                    6.0            518.0
# 27                217.0                    6.0            149.0
# 28               5072.0                    6.0            326.0
# 29               6167.0                    6.0           1552.0
# 30                719.0                    6.0            163.0
# ..                  ...                    ...              ...
# 321               111.0                    6.0            407.0
# 322              2254.0                    6.0            839.0
# 323               566.0                    6.0            185.0
# 324              4593.0                    6.0            599.0
# 325             29396.0                    6.0          13260.0
# 326             39346.0                    6.0           7717.0
# 328              1765.0                    6.0            265.0
# 329               367.0                    6.0            421.0
# 330               230.0                    6.0            498.0
# 331              1388.0                    6.0            566.0
# 332              2775.0                    6.0            739.0
# 333              1750.0                    6.0            252.0
# 334              4624.0                    6.0           2239.0
# 335               705.0                    6.0            335.0
# 336              1386.0                    6.0            547.0
# 337             13727.0                    6.0            699.0
# 338              1403.0                    6.0            238.0
# 339              1725.0                    6.0            164.0
# 340              2747.0                    6.0            312.0
# 341              3998.0                    6.0            564.0
# 342              2062.0                    6.0           1303.0
# 343               807.0                    6.0            185.0
# 344              4389.0                    6.0           1047.0
# 345              2655.0                    6.0            400.0
# 347             11452.0                    6.0           2852.0
# 348               977.0                    6.0            436.0
# 349             17658.0                    6.0           2111.0
# 350              1837.0                    6.0            905.0
# 351              1568.0                    6.0            314.0
# 352              8119.0                    6.0           1638.0
#
#      avg_cites_per_paper  article_influence journal_id
# 0               0.275510              0.030  1726-569X
# 1               3.086124              0.181  0365-0588
# 2               8.076923              0.230  0386-300X
# 3               0.984678              0.112  1646-0758
# 4               7.024834              0.506  0065-1400
# 5               0.735632              0.307  1807-8621
# 6               7.666667              0.187  1217-8837
# 7               1.129496              0.193  1280-8571
# 8               1.641509              0.113  1687-1847
# 9               0.505093              0.198  1687-8140
# 10              7.615385              0.601  1742-6405
# 11              1.000777              0.452  2158-3226
# 12              7.197917              1.902  1748-7188
# 13              3.000000              0.566  2191-0855
# 14             11.240157              0.740  1476-0711
# 15              5.129956              0.416  1744-859X
# 16              1.447368              0.224  0972-2327
# 17              6.026616              1.366  2110-5820
# 18              3.402266              0.369  1817-1737
# 19              2.296117              0.737  2041-2851
# 21              7.710345              0.521  1864-7790
# 22              0.923967              0.117  1733-3490
# 23             14.916991              1.559  1478-6354
# 24             10.040230              1.145  1759-0914
# 25              1.135659              0.520  2073-4433
# 26              5.654440              0.768  1530-261X
# 27              1.456376              0.080  1028-2092
# 28             15.558282              0.693  1744-9081
# 29              3.973582              0.683  1860-5397
# 30              4.411043              0.668  1756-0381
# ..                   ...                ...        ...
# 321             0.272727              0.077  1851-8265
# 322             2.686532              0.782  1757-7241
# 323             3.059459              0.134  0350-820X
# 324             7.667780              0.345  1678-992X
# 325             2.216893              1.482  2045-2322
# 326             5.098613              0.546  1424-8220
# 328             6.660377              0.605  1349-6476
# 329             0.871734              0.077  2222-3436
# 330             0.461847              0.076  2224-7890
# 331             2.452297              0.422  1944-3277
# 332             3.755074              1.123  1757-6512
# 333             6.944444              0.628  1747-597X
# 334             2.065208              0.333  2071-1050
# 335             2.104478              0.430  2073-8994
# 336             2.533821              0.611  1815-0659
# 337            19.638054              1.033  1600-0870
# 338             5.894958              0.167  1559-2448
# 339            10.518293              1.287  1940-3372
# 340             8.804487              0.376  1742-4682
# 341             7.088652              0.490  1178-203X
# 342             1.582502              0.147  0354-9836
# 343             4.362162              0.673  1617-9625
# 344             4.191977              0.805  2072-6651
# 345             6.637500              0.854  1936-5233
# 347             4.015428              0.893  1745-6215
# 348             2.240826              0.217  0375-8427
# 349             8.364756              0.635  1743-422X
# 350             2.029834              0.435  2073-4441
# 351             4.993631              0.557  1749-7922
# 352             4.956654              0.392  1477-7819
#
# [338 rows x 8 columns]

# %%
plt.plot(pivot_table_merged['article_influence'], 
         pivot_table_merged['citation_count_sum'], 'o')
plt.xlabel('2015 AI Score for Given Journal')
plt.ylabel('Citation Count per Journal 6 Years \n 2010-2015')


plt.savefig('ai_citation_ct_5_years_scatterplot.jpg')

# %%
plt.plot(pivot_table_merged['article_influence'], 
         pivot_table_merged['citation_count_sum'], 'o')
plt.xlabel('2015 AI Score for Given Journal')
plt.ylabel('Citation Count per Journal 6 Years \n 2010-2015')
plt.ylim(0,110000)
plt.xlim(0, 8)
plt.savefig('ai_citation_ct_5_years_scatterplot_zoomed.jpg')

# %%
linregress(pivot_table_merged['article_influence'], pivot_table_merged['citation_count_sum'])
# Out:
# LinregressResult(slope=5479.7435994663083, intercept=4378.3079765581606, rvalue=0.15148402527331556, pvalue=0.0052577020088959581, stderr=1950.6651845140079)

# %%
# Set seed for reproducibility
np.random.seed(72117)
# Split dataframe into test (20%) and train (80%)
pt_train, pt_test = train_test_split(pivot_table_merged, test_size = 0.20)

# %%
# Run linear regression with three features
pt_lr = smf.ols(formula=
                   'article_influence ~ citation_count_sum + paper_count_sum + avg_cites_per_paper', 
                data=pt_train).fit()
# Create an array of predictions for the training and testing data
pt_train_pred = pt_lr.predict(pt_train)
pt_test_pred = pt_lr.predict(pt_test)

# %%
# Output results of linear regression
pt_lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      article_influence   R-squared:                       0.243
# Model:                            OLS   Adj. R-squared:                  0.234
# Method:                 Least Squares   F-statistic:                     28.42
# Date:                Fri, 21 Jul 2017   Prob (F-statistic):           5.70e-16
# Time:                        09:28:18   Log-Likelihood:                -327.13
# No. Observations:                 270   AIC:                             662.3
# Df Residuals:                     266   BIC:                             676.6
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------
# Intercept               0.7913      0.054     14.638      0.000         0.685     0.898
# citation_count_sum   4.149e-05   4.67e-06      8.879      0.000      3.23e-05  5.07e-05
# paper_count_sum        -0.0002   2.42e-05     -8.352      0.000        -0.000    -0.000
# avg_cites_per_paper     0.0007      0.002      0.328      0.743        -0.003     0.005
# ==============================================================================
# Omnibus:                      227.377   Durbin-Watson:                   2.041
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3689.001
# Skew:                           3.389   Prob(JB):                         0.00
# Kurtosis:                      19.792   Cond. No.                     4.86e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.86e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Calculate the RMSE of the testing actual values versus predicted values
np.sqrt(mean_squared_error(pt_test['article_influence'], pt_test_pred))
# Out:
# 1.4733898156917509

# %%
# Run linear regression with three features
pt_log_lr = smf.ols(formula=
                   'np.log(article_influence) ~ np.log(citation_count_sum) + np.log(paper_count_sum) + np.log(avg_cites_per_paper)', 
                data=pt_train).fit()
# Create an array of predictions for the training and testing data
pt_log_train_pred = pt_log_lr.predict(pt_train)
pt_log_test_pred = pt_log_lr.predict(pt_test)

# %%
# Output results of linear regression
pt_log_lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     np.log(article_influence)   R-squared:                       0.431
# Model:                                   OLS   Adj. R-squared:                  0.427
# Method:                        Least Squares   F-statistic:                     101.3
# Date:                       Fri, 21 Jul 2017   Prob (F-statistic):           1.81e-33
# Time:                               09:28:18   Log-Likelihood:                -283.64
# No. Observations:                        270   AIC:                             573.3
# Df Residuals:                            267   BIC:                             584.1
# Df Model:                                  2
# Covariance Type:                   nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# Intercept                      -3.1557      0.241    -13.069      0.000        -3.631    -2.680
# np.log(citation_count_sum)      0.2754      0.020     14.047      0.000         0.237     0.314
# np.log(paper_count_sum)         0.0010      0.025      0.038      0.970        -0.048     0.050
# np.log(avg_cites_per_paper)     0.2744      0.029      9.438      0.000         0.217     0.332
# ==============================================================================
# Omnibus:                       26.311   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              111.344
# Skew:                          -0.158   Prob(JB):                     6.64e-25
# Kurtosis:                       6.130   Cond. No.                     3.43e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.54e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# Calculate the RMSE of the log of testing actual values versus predicted (log) values
np.sqrt(mean_squared_error(np.log(pt_test['article_influence']), pt_log_test_pred))
# Out:
# 0.61684121391405322

# %%
# Run linear regression with two features
pt_log_lr2 = smf.ols(formula=
                   'np.log(article_influence) ~ np.log(citation_count_sum) + np.log(avg_cites_per_paper)', 
                data=pt_train).fit()
# Create an array of predictions for the training and testing data
pt_log_train_pred2 = pt_log_lr2.predict(pt_train)
pt_log_test_pred2 = pt_log_lr2.predict(pt_test)

# %%
# Output results of linear regression
pt_log_lr2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     np.log(article_influence)   R-squared:                       0.431
# Model:                                   OLS   Adj. R-squared:                  0.427
# Method:                        Least Squares   F-statistic:                     101.3
# Date:                       Fri, 21 Jul 2017   Prob (F-statistic):           1.81e-33
# Time:                               09:28:18   Log-Likelihood:                -283.64
# No. Observations:                        270   AIC:                             573.3
# Df Residuals:                            267   BIC:                             584.1
# Df Model:                                  2
# Covariance Type:                   nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# Intercept                      -3.1557      0.241    -13.069      0.000        -3.631    -2.680
# np.log(citation_count_sum)      0.2763      0.034      8.086      0.000         0.209     0.344
# np.log(avg_cites_per_paper)     0.2735      0.051      5.414      0.000         0.174     0.373
# ==============================================================================
# Omnibus:                       26.311   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              111.344
# Skew:                          -0.158   Prob(JB):                     6.64e-25
# Kurtosis:                       6.130   Cond. No.                         48.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Calculate the RMSE of the log of testing actual values versus predicted (log) values
np.sqrt(mean_squared_error(np.log(pt_test['article_influence']), pt_log_test_pred2))
# Out:
# 0.61684121391405333
